# %% [markdown]
# In this lecture, we include:
# 1. Summary Functions
# 2. Maps
# ___
# For this assignment we will be using the same **winemag-data-130k-v2.csv** dataset

# %%
import pandas as pd
reviews = pd.read_csv("Datasets/winemag-data-130k-v2.csv", index_col=0)

# %% [markdown]
# # Summary Functions

# %% [markdown]
# Pandas provides many simple "summary functions" (not an official name) which restructure the data in some useful way.

# %% [markdown]
# **describe():** <br>
# This method generates a high-level summary of the attributes of the given column.<br>
# It is type-aware, meaning that its output changes based on the data type of the input.

# %%
#Observe the summary - 'points' column holds numeric values
reviews.points.describe()

# %%
#Observe the summary - 'taster_name' column holds string values
reviews.taster_name.describe()

# %% [markdown]
# **mean():** <br>
# To find the mean of data within a numeric column

# %%
#For example: Find the average of points of all the wines in the dataset

# %%
reviews.points.mean()

# %% [markdown]
# **unique():** <br>
# To find a list of unique values within a column

# %%
#For example: Find the names of unique wine tasters

# %%
reviews.taster_name.unique()

# %% [markdown]
# **value_counts():** <br>
# To find a list of unique values with a count of number of occurences

# %%
#For example: Find the names of unique wine tasters with counts

# %%
reviews.taster_name.value_counts()

# %% [markdown]
# ____

# %% [markdown]
# # Maps:
# A map is a term, borrowed from mathematics, for a function that takes one set of values and "maps" them to another set of values. In data science we often have a need for creating new representations from existing data, or for transforming data from the format it is in now to the format that we want it to be in later. Maps are what handle this work, making them extremely important for getting your work done!
#
# There are two mapping methods that you will use often.

# %% [markdown]
# 1. map() is the first, and slightly simpler one.

# %% [markdown]
# For example, suppose that we wanted to remean the scores the wines received to 0. We can do this as follows:

# %%
review_points_mean = reviews.points.mean()
reviews.points.map(lambda p: p - review_points_mean)

# %% [markdown]
# 2. apply() is the second.

# %% [markdown]
# It is an equivalent method if we want to transform a whole DataFrame by calling a custom method on each row.

# %%
def remean_points(row):
    row.points = row.points - review_points_mean
    return row

reviews.apply(remean_points, axis='columns')
